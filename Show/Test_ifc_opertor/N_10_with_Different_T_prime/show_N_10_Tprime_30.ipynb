# %%
import sys
import os
import pickle
sys.path.append("/root/autodl-tmp/HSPS/IFC/")
# pkl
path = '/root/autodl-tmp/HSPS/IFC/Checkpoints/Operator/IFC_Opertor_N_10_Tprime_30.pkl'

# %%
# load
with open(path, 'rb') as file:
    loaded_object = pickle.load(file)

# %%
model = loaded_object.best_model

loaded_object.prepare_dataset(npz_path= loaded_object.config["Data_In"]["path"])
# Out:
# raw_data_numpy torch.Size([216, 80, 64, 100])

# %%
dataloader = loaded_object.test_loader

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

# 假设dataloader、model已经定义

MC_test = 50 # 50  big for uncertanity 
MC_test_DICT= {"C1":[],"C2":[],"C3":[],"C4":[]}
mc = 100 # for the T prime mc
model = model.train()
for Mc in range (MC_test):
    predictions = [[] for _ in range(4)]  # 为每个分类器预先创建列表
    true_labels_list = [[] for _ in range(4)]  # 修改变量名以避免冲突
    with torch.no_grad():
        for mc in range(50): # T_prime
            for data, conditions, label in dataloader:
                data = data.cuda()
                outputs = model(data)
                latent = model.latent  # [b, 512]

                for i in range(4):  # calssifer -4 
                    _, predicted = torch.max(outputs[:, i, :], 1)  # 获取最大值的索引作为预测类别
                    predictions[i].extend(predicted.cpu().numpy())
                    true_labels_list[i].extend(label[:, i].cpu().numpy())

        # 绘制每个分类器的预测结果的柱状图
        num_classifiers = len(predictions)
        #fig, axes = plt.subplots(num_classifiers, 2, figsize=(12, num_classifiers * 5))  # 增加图的宽度以更好地展示

        for i in range(num_classifiers):
            # ax_pred = axes[i, 0]
            # ax_true = axes[i, 1]
        
            # # 预测结果的柱状图
            # pred_labels, pred_counts = np.unique(predictions[i], return_counts=True)
            # ax_pred.bar(pred_labels, pred_counts, color='blue', alpha=0.7)
            
            # ax_pred.set_xlabel('Predicted Classes')
            # ax_pred.set_ylabel('Frequency')

            # # 真实标签的柱状图
            # true_labels, true_counts = np.unique(true_labels_list[i], return_counts=True)
            # ax_true.bar(true_labels, true_counts, color='green', alpha=0.7)
            # ax_true.set_title(f'Classifier {i+1} True')
            # ax_true.set_xlabel('True Classes')
            # ax_true.set_ylabel('Frequency')
            #将列表转换为NumPy数组以便更容易地进行运算
            preds = np.array(predictions[i])
            labels = np.array(true_labels_list[i])
            
            # 计算准确率
            accuracy = np.mean(preds == labels) * 100
            #ax_pred.set_title(f'Classifier {i+1} Predicted acc is {accuracy:.2f}%')
            MC_test_DICT[f"C{i+1}"].append(accuracy)
            print(f'In MC {Mc}Classifier {i+1} Predicted acc is {accuracy:.2f}')
        # plt.tight_layout()
        # plt.show()
# Out:
# In MC 0Classifier 1 Predicted acc is 92.32
# In MC 0Classifier 2 Predicted acc is 78.41
# In MC 0Classifier 3 Predicted acc is 72.05
# In MC 0Classifier 4 Predicted acc is 86.41
# In MC 1Classifier 1 Predicted acc is 91.73
# In MC 1Classifier 2 Predicted acc is 78.05
# In MC 1Classifier 3 Predicted acc is 72.41
# In MC 1Classifier 4 Predicted acc is 87.00
# In MC 2Classifier 1 Predicted acc is 92.77
# In MC 2Classifier 2 Predicted acc is 78.05
# In MC 2Classifier 3 Predicted acc is 71.64
# In MC 2Classifier 4 Predicted acc is 86.77
# In MC 3Classifier 1 Predicted acc is 91.91
# In MC 3Classifier 2 Predicted acc is 78.45
# In MC 3Classifier 3 Predicted acc is 71.64
# In MC 3Classifier 4 Predicted acc is 85.86
# In MC 4Classifier 1 Predicted acc is 92.23
# In MC 4Classifier 2 Predicted acc is 78.05
# In MC 4Classifier 3 Predicted acc is 70.86
# In MC 4Classifier 4 Predicted acc is 87.23
# In MC 5Classifier 1 Predicted acc is 92.55
# In MC 5Classifier 2 Predicted acc is 77.95
# In MC 5Classifier 3 Predicted acc is 72.14
# In MC 5Classifier 4 Predicted acc is 86.73
# In MC 6Classifier 1 Predicted acc is 92.18
# In MC 6Classifier 2 Predicted acc is 78.32
# In MC 6Classifier 3 Predicted acc is 71.41
# In MC 6Classifier 4 Predicted acc is 85.18
# In MC 7Classifier 1 Predicted acc is 92.95
# In MC 7Classifier 2 Predicted acc is 76.95
# In MC 7Classifier 3 Predicted acc is 71.09
# In MC 7Classifier 4 Predicted acc is 86.36
# In MC 8Classifier 1 Predicted acc is 92.41
# In MC 8Classifier 2 Predicted acc is 78.36
# In MC 8Classifier 3 Predicted acc is 71.55
# In MC 8Classifier 4 Predicted acc is 86.09
# In MC 9Classifier 1 Predicted acc is 92.05
# In MC 9Classifier 2 Predicted acc is 78.00
# In MC 9Classifier 3 Predicted acc is 72.55
# In MC 9Classifier 4 Predicted acc is 86.09
# In MC 10Classifier 1 Predicted acc is 92.55
# In MC 10Classifier 2 Predicted acc is 77.41
# In MC 10Classifier 3 Predicted acc is 71.41
# In MC 10Classifier 4 Predicted acc is 87.64
# In MC 11Classifier 1 Predicted acc is 92.59
# In MC 11Classifier 2 Predicted acc is 77.32
# In MC 11Classifier 3 Predicted acc is 72.64
# In MC 11Classifier 4 Predicted acc is 87.55
# In MC 12Classifier 1 Predicted acc is 92.82
# In MC 12Classifier 2 Predicted acc is 77.73
# In MC 12Classifier 3 Predicted acc is 70.95
# In MC 12Classifier 4 Predicted acc is 86.55
# In MC 13Classifier 1 Predicted acc is 92.41
# In MC 13Classifier 2 Predicted acc is 77.36
# In MC 13Classifier 3 Predicted acc is 72.05
# In MC 13Classifier 4 Predicted acc is 85.77
# In MC 14Classifier 1 Predicted acc is 92.18
# In MC 14Classifier 2 Predicted acc is 78.00
# In MC 14Classifier 3 Predicted acc is 71.27
# In MC 14Classifier 4 Predicted acc is 88.27
# In MC 15Classifier 1 Predicted acc is 91.68
# In MC 15Classifier 2 Predicted acc is 78.32
# In MC 15Classifier 3 Predicted acc is 72.18
# In MC 15Classifier 4 Predicted acc is 86.50
# In MC 16Classifier 1 Predicted acc is 91.41
# In MC 16Classifier 2 Predicted acc is 78.05
# In MC 16Classifier 3 Predicted acc is 70.68
# In MC 16Classifier 4 Predicted acc is 85.82
# In MC 17Classifier 1 Predicted acc is 91.73
# In MC 17Classifier 2 Predicted acc is 77.41
# In MC 17Classifier 3 Predicted acc is 71.77
# In MC 17Classifier 4 Predicted acc is 85.23
# In MC 18Classifier 1 Predicted acc is 91.86
# In MC 18Classifier 2 Predicted acc is 78.27
# In MC 18Classifier 3 Predicted acc is 72.05
# In MC 18Classifier 4 Predicted acc is 85.55
# In MC 19Classifier 1 Predicted acc is 92.18
# In MC 19Classifier 2 Predicted acc is 77.82
# In MC 19Classifier 3 Predicted acc is 73.05
# In MC 19Classifier 4 Predicted acc is 86.41
# In MC 20Classifier 1 Predicted acc is 92.55
# In MC 20Classifier 2 Predicted acc is 77.91
# In MC 20Classifier 3 Predicted acc is 72.59
# In MC 20Classifier 4 Predicted acc is 87.00
# In MC 21Classifier 1 Predicted acc is 92.82
# In MC 21Classifier 2 Predicted acc is 78.50
# In MC 21Classifier 3 Predicted acc is 71.00
# In MC 21Classifier 4 Predicted acc is 87.09
# In MC 22Classifier 1 Predicted acc is 91.41
# In MC 22Classifier 2 Predicted acc is 77.73
# In MC 22Classifier 3 Predicted acc is 72.23
# In MC 22Classifier 4 Predicted acc is 86.05
# In MC 23Classifier 1 Predicted acc is 92.09
# In MC 23Classifier 2 Predicted acc is 77.50
# In MC 23Classifier 3 Predicted acc is 72.73
# In MC 23Classifier 4 Predicted acc is 85.59
# In MC 24Classifier 1 Predicted acc is 91.36
# In MC 24Classifier 2 Predicted acc is 78.18
# In MC 24Classifier 3 Predicted acc is 73.36
# In MC 24Classifier 4 Predicted acc is 87.95
# In MC 25Classifier 1 Predicted acc is 92.59
# In MC 25Classifier 2 Predicted acc is 77.86
# In MC 25Classifier 3 Predicted acc is 71.95
# In MC 25Classifier 4 Predicted acc is 86.18
# In MC 26Classifier 1 Predicted acc is 92.82
# In MC 26Classifier 2 Predicted acc is 78.45
# In MC 26Classifier 3 Predicted acc is 72.32
# In MC 26Classifier 4 Predicted acc is 87.41
# In MC 27Classifier 1 Predicted acc is 92.95
# In MC 27Classifier 2 Predicted acc is 77.59
# In MC 27Classifier 3 Predicted acc is 72.14
# In MC 27Classifier 4 Predicted acc is 87.18
# In MC 28Classifier 1 Predicted acc is 91.86
# In MC 28Classifier 2 Predicted acc is 78.05
# In MC 28Classifier 3 Predicted acc is 71.77
# In MC 28Classifier 4 Predicted acc is 85.59
# In MC 29Classifier 1 Predicted acc is 92.18
# In MC 29Classifier 2 Predicted acc is 78.77
# In MC 29Classifier 3 Predicted acc is 71.82
# In MC 29Classifier 4 Predicted acc is 85.95
# In MC 30Classifier 1 Predicted acc is 91.82
# In MC 30Classifier 2 Predicted acc is 77.91
# In MC 30Classifier 3 Predicted acc is 71.91
# In MC 30Classifier 4 Predicted acc is 86.00
# In MC 31Classifier 1 Predicted acc is 91.86
# In MC 31Classifier 2 Predicted acc is 78.23
# In MC 31Classifier 3 Predicted acc is 71.14
# In MC 31Classifier 4 Predicted acc is 85.68
# In MC 32Classifier 1 Predicted acc is 92.55
# In MC 32Classifier 2 Predicted acc is 78.41
# In MC 32Classifier 3 Predicted acc is 71.68
# In MC 32Classifier 4 Predicted acc is 85.36
# In MC 33Classifier 1 Predicted acc is 92.27
# In MC 33Classifier 2 Predicted acc is 78.14
# In MC 33Classifier 3 Predicted acc is 70.73
# In MC 33Classifier 4 Predicted acc is 85.41
# In MC 34Classifier 1 Predicted acc is 91.77
# In MC 34Classifier 2 Predicted acc is 78.23
# In MC 34Classifier 3 Predicted acc is 72.36
# In MC 34Classifier 4 Predicted acc is 86.36
# In MC 35Classifier 1 Predicted acc is 92.50
# In MC 35Classifier 2 Predicted acc is 78.09
# In MC 35Classifier 3 Predicted acc is 73.23
# In MC 35Classifier 4 Predicted acc is 85.64
# In MC 36Classifier 1 Predicted acc is 92.32
# In MC 36Classifier 2 Predicted acc is 76.86
# In MC 36Classifier 3 Predicted acc is 71.77
# In MC 36Classifier 4 Predicted acc is 86.68
# In MC 37Classifier 1 Predicted acc is 92.14
# In MC 37Classifier 2 Predicted acc is 77.50
# In MC 37Classifier 3 Predicted acc is 71.68
# In MC 37Classifier 4 Predicted acc is 85.45
# In MC 38Classifier 1 Predicted acc is 92.41
# In MC 38Classifier 2 Predicted acc is 77.95
# In MC 38Classifier 3 Predicted acc is 73.14
# In MC 38Classifier 4 Predicted acc is 85.86
# In MC 39Classifier 1 Predicted acc is 92.32
# In MC 39Classifier 2 Predicted acc is 77.45
# In MC 39Classifier 3 Predicted acc is 71.45
# In MC 39Classifier 4 Predicted acc is 86.73
# In MC 40Classifier 1 Predicted acc is 92.64
# In MC 40Classifier 2 Predicted acc is 78.32
# In MC 40Classifier 3 Predicted acc is 70.95
# In MC 40Classifier 4 Predicted acc is 86.86
# In MC 41Classifier 1 Predicted acc is 92.23
# In MC 41Classifier 2 Predicted acc is 77.64
# In MC 41Classifier 3 Predicted acc is 71.64
# In MC 41Classifier 4 Predicted acc is 86.64
# In MC 42Classifier 1 Predicted acc is 92.05
# In MC 42Classifier 2 Predicted acc is 78.32
# In MC 42Classifier 3 Predicted acc is 71.86
# In MC 42Classifier 4 Predicted acc is 86.32
# In MC 43Classifier 1 Predicted acc is 91.73
# In MC 43Classifier 2 Predicted acc is 78.73
# In MC 43Classifier 3 Predicted acc is 72.14
# In MC 43Classifier 4 Predicted acc is 86.18
# In MC 44Classifier 1 Predicted acc is 92.73
# In MC 44Classifier 2 Predicted acc is 76.64
# In MC 44Classifier 3 Predicted acc is 72.95
# In MC 44Classifier 4 Predicted acc is 86.23
# In MC 45Classifier 1 Predicted acc is 91.86
# In MC 45Classifier 2 Predicted acc is 77.18
# In MC 45Classifier 3 Predicted acc is 71.82
# In MC 45Classifier 4 Predicted acc is 85.41
# In MC 46Classifier 1 Predicted acc is 91.45
# In MC 46Classifier 2 Predicted acc is 78.82
# In MC 46Classifier 3 Predicted acc is 71.68
# In MC 46Classifier 4 Predicted acc is 86.68
# In MC 47Classifier 1 Predicted acc is 92.77
# In MC 47Classifier 2 Predicted acc is 78.59
# In MC 47Classifier 3 Predicted acc is 73.36
# In MC 47Classifier 4 Predicted acc is 85.18
# In MC 48Classifier 1 Predicted acc is 92.45
# In MC 48Classifier 2 Predicted acc is 78.36
# In MC 48Classifier 3 Predicted acc is 72.36
# In MC 48Classifier 4 Predicted acc is 86.77
# In MC 49Classifier 1 Predicted acc is 92.45
# In MC 49Classifier 2 Predicted acc is 78.82
# In MC 49Classifier 3 Predicted acc is 71.86
# In MC 49Classifier 4 Predicted acc is 86.95

# %%
for i in range(4):  # 对于每个分类器
   mean = np.mean(MC_test_DICT[f"C{i+1}"]) # Uncertainty
   std = np.std(MC_test_DICT[f"C{i+1}"]) # Uncertainty
   
   print(f'Classifier {i+1} Accuracy: {mean:.4f} std:{std}')
# Out:
# Classifier 1 Accuracy: 92.2291 std:0.42250336200921784
# Classifier 2 Accuracy: 77.9800 std:0.5001784805413899
# Classifier 3 Accuracy: 71.9400 std:0.6739203180208488
# Classifier 4 Accuracy: 86.3482 std:0.7339246926936402
