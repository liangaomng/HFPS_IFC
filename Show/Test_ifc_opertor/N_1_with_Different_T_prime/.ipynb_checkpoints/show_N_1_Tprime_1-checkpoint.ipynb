# %%
import sys
import os
import pickle
sys.path.append("/root/autodl-tmp/HSPS/IFC/")
# pkl
path = '/root/autodl-tmp/HSPS/IFC/Checkpoints/Operator/IFC_Opertor_N_1_Tprime_1.pkl'
from Test.test import Test_method

# %%
t_method = Test_method(checkpoint_path= path,
                       task= "operator_N_1_Tprime_1")
# Out:
# raw_data_numpy torch.Size([216, 80, 64, 100])
# raw_data_numpy torch.Size([216, 80, 64, 100])

# %%
import matplotlib.pyplot as plt
plt.plot(t_method.checkpoint.valid_loss,label="valid")
plt.plot(t_method.checkpoint.train_loss,label="train")
plt.yscale('log')

# Adding labels and title for clarity
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
t_method.MC_test()
# Out:
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# T_prime_mc_number is {mc}
# ...
